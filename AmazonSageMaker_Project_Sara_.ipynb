# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraIrfa/AWS-SageMakerStudio/blob/main/AmazonSageMaker_Project_Sara_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing libraries for various functionalities

# python-dotenv: Allows you to manage environment variables in a .env file.
# !pip install python-dotenv

# openai: Provides access to the OpenAI GPT-3 language model and API.
# !pip install openai

# youtube_dl: A tool for downloading videos and audios from YouTube.
# !pip install youtube_dl

# youtube_transcript_api: Allows you to fetch YouTube video transcripts.
# !pip install youtube_transcript_api

# torchaudio: A PyTorch-based library for audio processing and analysis.
# !pip install torchaudio

# sentencepiece: A library for text segmentation and tokenization, useful for NLP tasks.
# !pip install sentencepiece

# sacremoses: A tokenization and detokenization library for natural language processing.
# !pip install sacremoses

# transformers: Provides pre-trained models and utilities for NLP tasks using the Hugging Face Transformers library.
# !pip install transformers
# Out:
# Requirement already satisfied: python-dotenv in ./.conda/envs/default/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: openai in ./.conda/envs/default/lib/python3.9/site-packages (0.27.10)
# Requirement already satisfied: tqdm in ./.conda/envs/default/lib/python3.9/site-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in ./.conda/envs/default/lib/python3.9/site-packages (from openai) (3.8.5)
# Requirement already satisfied: requests>=2.20 in ./.conda/envs/default/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.conda/envs/default/lib/python3.9/site-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: youtube_dl in ./.conda/envs/default/lib/python3.9/site-packages (2021.12.17)
# Requirement already satisfied: youtube_transcript_api in ./.conda/envs/default/lib/python3.9/site-packages (0.6.1)
# Requirement already satisfied: requests in ./.conda/envs/default/lib/python3.9/site-packages (from youtube_transcript_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->youtube_transcript_api) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->youtube_transcript_api) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->youtube_transcript_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->youtube_transcript_api) (3.4)
# Requirement already satisfied: torchaudio in ./.conda/envs/default/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: torch==2.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from torchaudio) (2.0.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (8.5.0.96)
# Requirement already satisfied: jinja2 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (3.1.2)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (10.9.0.58)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.7.99)
# Requirement already satisfied: filelock in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (3.12.3)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (2.14.3)
# Requirement already satisfied: networkx in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (3.1)
# Requirement already satisfied: sympy in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.7.99)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.4.0.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.7.91)
# Requirement already satisfied: typing-extensions in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (4.7.1)
# Requirement already satisfied: triton==2.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (2.0.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.conda/envs/default/lib/python3.9/site-packages (from torch==2.0.1->torchaudio) (11.10.3.66)
# Requirement already satisfied: setuptools in ./.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchaudio) (68.0.0)
# Requirement already satisfied: wheel in ./.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchaudio) (0.41.1)
# Requirement already satisfied: lit in ./.conda/envs/default/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->torchaudio) (16.0.6)
# Requirement already satisfied: cmake in ./.conda/envs/default/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1->torchaudio) (3.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jinja2->torch==2.0.1->torchaudio) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/envs/default/lib/python3.9/site-packages (from sympy->torch==2.0.1->torchaudio) (1.3.0)
# Requirement already satisfied: sentencepiece in ./.conda/envs/default/lib/python3.9/site-packages (0.1.99)
# Requirement already satisfied: sacremoses in ./.conda/envs/default/lib/python3.9/site-packages (0.0.53)
# Requirement already satisfied: six in ./.conda/envs/default/lib/python3.9/site-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: tqdm in ./.conda/envs/default/lib/python3.9/site-packages (from sacremoses) (4.66.1)
# Requirement already satisfied: regex in ./.conda/envs/default/lib/python3.9/site-packages (from sacremoses) (2023.8.8)
# Requirement already satisfied: click in ./.conda/envs/default/lib/python3.9/site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in ./.conda/envs/default/lib/python3.9/site-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: transformers in ./.conda/envs/default/lib/python3.9/site-packages (4.32.1)
# Requirement already satisfied: requests in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: tqdm>=4.27 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: numpy>=1.17 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: filelock in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (3.12.3)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: fsspec in ./.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (3.2.0)

# %%
import re  # Regular expression support for text manipulation
from youtube_transcript_api import YouTubeTranscriptApi  # Fetch YouTube video transcripts
import torch  # PyTorch for machine learning capabilities
import torchaudio  # Audio processing using PyTorch's torchaudio library
import openai  # Access OpenAI's APIs and language models
import textwrap  # Text formatting and paragraph wrapping
from transformers import pipeline  # Utilize pre-trained NLP models via Transformers library

# %%
######################################
# Specify the YouTube video URL
######################################
youtube_url = "https://www.youtube.com/watch?v=IRyC6QyBY58"



######################################
# Extract the video ID using regular expressions
######################################
# Search for the pattern "v=..." in the YouTube URL
match = re.search(r"v=([A-Za-z0-9_-]+)", youtube_url)
if match:
    # If a match is found, extract the video ID using group(1)
    video_id = match.group(1)
else:
    # If no match is found, raise an error indicating an invalid URL
    raise ValueError("Invalid YouTube URL")



######################################
# Get the transcript from YouTube
######################################
# Use the YouTubeTranscriptApi to fetch the transcript of the video
transcript = YouTubeTranscriptApi.get_transcript(video_id)




######################################
# Concatenate the transcript into a single string
######################################
# Initialize an empty string to store the concatenated transcript
transcript_text = ""
# Iterate through each segment (dictionary) in the transcript
for segment in transcript:
    # Append the text from the current segment to the transcript_text
    transcript_text += segment["text"] + " "




######################################
# Print the concatenated transcript text
######################################
# Display the complete concatenated transcript on the console
print(transcript_text)
# Out:
# - Do you want to remake
# the way we make things? If your answer is yes, you
# are at the right place. Welcome everyone. My name is Muhammad Sajid. I'm a Solutions Architect at AWS. With me, I have Marcus Ulmefors, Director Data and Machine
# Learning Platforms at Northvolt. He's here to talk about how Europe's first homegrown
# gigafactory, Northvolt, is producing sustainable back batteries in their connected factory. You will meet Marcus very soon. Both me and Marcus are
# from Stockholm, Sweden. All right, I have a habit of
# keeping my browser tabs open. There is a special term for
# this called "Tab-tsundoku." Tsundoku is a Japanese word for impulsively acquiring
# and piling up books, without ever intending to read them. So raise your hands if your
# browser looks like this on a daily basis. Welcome to the club. (chuckles) But we can't keep
# opening new tabs forever. Anything we can't keep doing forever is obviously not sustainable. So you're not here to listen
# to my unsustainable habits. You are here attending a
# Level 300 breakout session, where you will learn how
# manufacturing customers are leveraging AWS in their
# sustainability journey. Let me ask you a question. Raise your hand if you are responsible for sustainability at your company. (audience murmurs) I expected every one of
# you to raise your hands. You know why? Just like security, sustainability is
# everyone's responsibility. Let's look at the agenda. Today, you will learn how
# manufacturers can use data to become more sustainable. What are some of the modern
# technologies you can use to optimize factory operations? I will also show you a short
# demo of AWS IoT TwinMaker, and obviously Marcus
# from Northvolt will share his or their experience of using AWS to operate connected factory. In the end, I will leave you
# with some call to actions and learning resources. So are you ready? Show some excitement. Are you ready? - Yeah!
# - Yes! (audience cheers)
# (audience members chuckle) - Do you know what is the
# average temperature of the Earth? Raise your hands. Today, the global average temperature is about 15 degrees Celsius and
# increasing faster than ever. The 20 warmest years on record have been in the past 20 years. So research says average
# global temperature may rise by three to five degrees by the end of this century, until 2100. Scientists also tell us that
# we have a limited window to make unprecedented headway in order to limit global
# warming to 1.5 degrees Celsius by the year 2050. And why this is important, this is important to avoid
# serious climate issues, including heat waves,
# floods, harsh weather, and you know, all those possible things, including the possibility of extinction of several living species. But my question is, why earth's
# temperature is increasing? A lot of global warming is happening due to the greenhouse gases
# generated by human activities. So what are the greenhouse gases? Greenhouse gases trap
# heat in earth's atmosphere that in return, makes
# the planet much hotter. There are many different greenhouse gases, including carbon dioxide,
# methane, nitrous oxide, and many more. The collective term "greenhouse gases" also goes by the more scientific name called carbon dioxide equivalent. And this is the 50 billion
# tons, or 50 gigatons, that we are dealing with every year. Out of this 50 gigatons, how much do you think is contributed by the manufacturing sector? Roughly 21%, or approximately
# 10 gigatons, every year Let me put this into perspective. So one gigaton is roughly
# 200 million elephants, if stacked vertically
# on top of each other, would stretch all the way
# from earth to the moon. Hence the 10 gigaton is
# 10 stacks of elephants stretching from the earth to the moon, and we don't have to be alive and wait until the end of the century to see the consequences
# of the climate change. For example, this year
# around 33 million people, including 16 million children, have been impacted in my
# native country, Pakistan, by the devastating flood
# caused by climate change. So 33 million people, there are more people than
# the combined population of all the Nordic countries, and these are more people than
# the population of Texas State that were impacted. So the picture you see here, this is the before the
# floods satellite image where you can see Pakistan's
# largest fresh water lake called Manchar. After the floods, there
# is no sign of fresh water, just the stagnant, contaminated water, which is just a breeding ground, acting as a breeding
# ground for mosquitoes. As I said, we don't have to wait. Future is already here. It's
# just not evenly distributed. And obviously, manufacturing
# has an outsized impact on the environment. According to the IEA, industrial
# activity in the year 2021 was directly responsible for
# emitting 9.4 gigatons of CO2. And by the way, this does not
# include the indirect emissions from electricity used
# for industrial processes. According to the same report, fossil fuels remain the
# dominant source of energy for industry. The manufacturing industry
# contributes significantly to greenhouse gases, and use, and manufacturers use a
# lot of water and energy. That's the reason, I mean, manufacturing are also
# the most targeted industry in sense of sustainability. And obviously we have more
# opportunity to improve, but there are trends in manufacturing that can help reduce
# negative climate impact. We are experiencing the fourth
# industrial revolution live. The first revolution brought
# mechanical innovations, like steam engine, cotton
# spinning, and railroads. Second brought the mass production through assembly lines
# and electrification. Third, which is my favorite by the way, brought computers and the internet. The fourth revolution is
# bringing physical, digital, and biological systems together. And industry 4.0 is reinventing the entire manufacturing process around the power of the data and cloud. Manufacturing is one of
# the largest producers of the data that customers
# can use to improve insights to become more sustainable
# and more profitable. But what is the challenge? The biggest challenge
# within the plant floor for a majority of
# manufacturers is visibility into operational technology data from machines and basic control systems. So let's see how industries
# have been using data, and where they are going now. Are you aware of the ISA95 framework? Raise your hands. So ISA95 is the international standard for the integration of
# enterprise and control systems, which is a traditional
# model before the cloud era. Traditionally, manufacturing
# technology has been split into operational versus
# information technology, where operational technology, or OT, has focused on the sensors and software, softwares that monitor and control the manufacturing process. And information technology,
# IT, has provided the separate function of data
# processing and analytics. So ISA95 model consists of field and control
# and management levels. The field and control levels consist of basic control systems, like supervisory control and
# data acquisition, or SCADA, and programmable logic controller and distributed control systems. The management level consists
# of business logistics and manufacturing operations. Operating systems like
# manufacturing execution system, MES, product life cycle management, and ERPs. So historically, this
# monolithic model was good before the cloud and edge computing era. It created data silos, and integration was a huge challenge, due to over 300 commercial, industrial communication protocols. With the cloud and open
# platform communication unified architecture, or OPCUA, the traditional model has
# evolved significantly, and IT-OT divide is minimized. With IT-OT convergence, operation technology
# environments are leveraging more IT solutions in the cloud to improve productivity and efficiency of production operations. But what about today? Today, in the time of
# physical meets digital, with increased computational
# power and connectivity, IT-OT border is invisible, and industries are adopting
# hybrid edge cloud architectures. And why did they do this? To run latency critical system on the edge close to the factory floor
# where all the action happens, and send volumes of data
# to the cloud for analytics, BI, and machine learning operations. So what makes sustainable
# manufacturing a possibility? Modern technologies. So, there are a lot of ways
# manufacturing customers can use data to become more
# sustainable and more profitable. I will share just a few examples with you. You can lower electricity,
# heating and cooling needs of a building by occupancy
# detection, better insulation and ventilation systems. Similarly, upgrading to smart
# LED lighting in buildings and elevators can help reduce your
# energy usage by up to 75%. By the way, are you aware of, that AWS is going to be
# water positive by year 2030? And what does that mean? It means AWS will be providing
# more water to the environment than it consumes for its own operations. So just like humans, machines can now tell you what
# they're feeling right now. Are they feeling good or bad? So, according to McKinsey,
# predictive maintenance can increase production
# line availability by 5-15% and reduce maintenance costs by 18-25%. With Amazon Monitron, you can monitor and detect
# abnormal machine behavior and enable predictive maintenance. Monitron is like a
# smart watch for machine. You stick it to a machine, and you start getting
# temperature and vibration data for that machine. So, raise your hand if you
# know the average lifespan of a factory equipment or an asset. Roughly 18 to 22 years. And with predictive maintenance, you can improve overall
# equipment efficiency, OEE, and lifespan of a machine even further, more than even 22 years. So digitization enhances
# shop floor safety as well. Factory buildings can use
# temperature, air quality, and occupancy data to improve
# staff safety and comfort. As I said in the beginning, data is the key enabler for
# sustainable manufacturing, and today it is possible to collect volume and a variety of data
# using industrial IoT. But collecting data is easy. Realizing value from data is challenging. According to the World Economic Forum, effective use of data in
# manufacturing can make businesses more sustainable and more profitable. That said, only 39% of executives they surveyed said they were able to scale a use case outside of a single
# product's production process. Similarly, Forbes recently surveyed more than 400 manufacturing
# executives in United States and the UK, United Kingdom. Only 44% of respondents said recent modernization
# efforts have provided them with actionable data, while 19% have not
# harnessed any data inside, I'm going to focus on
# just a few AWS services that fast track adding
# digitization to your factory, and Northvolt will
# explain their architecture that incorporates even more aspects. And cloud is the catalyst for achieving these
# industry 4.0 capabilities. AWS IoT and ad services
# allows you to ingest industrial IoT data to build
# smart factory capabilities. Similarly, industrial customers can harness virtually
# unlimited compute AIML and analytics capabilities
# using AWS cloud. So one way to gain insights from the data stranded between
# the four walls of a factory is to extend cloud
# capabilities to the edge, that is bringing cloud to the edge. So today, industrial companies
# want to ingest, store, and analyze IoT data closer to the point where data is generated,
# where all the action happens, which is the factory floor. So why they wanna do that, to enable predictive maintenance, improve overall equipment efficiency and enhance worker safety
# and even more things. So industrial customers can
# greatly benefit from the edge to keep data and compute local to the low latency environment. They might have intermittent connectivity and evidence to regulations,
# regulatory guidelines. And by the way, transferring huge volume
# of data to the cloud is also, economically,
# not very beneficial. So, here is a subset of the
# purpose built AWS services, to support industrial customers to build smart factory capabilities. Inside the factory, AWS
# ad services communicate with the industrial equipment, collecting and analyzing
# data, sending commands, and running local applications. Data sources at the edge
# may include SCADA systems, third party protocol
# converters, data historians, and even web APIs. You can ingest data directly using AWS Lambda or AWS IoT Greengrass, or use AWS IoT SiteWise for data that requires asset modeling. Once your data is in the cloud, you can use Amazon S3 as a data lake to store volume and variety
# of factory operational data. So you can use multiple AWS services to enrich and analyze the data. For instance, users can
# apply data science tools, such as Amazon SageMaker to provide insights from
# machinery across the shop floor. So let's go one step further. With the digital twin, you can improve the physical
# twin through rich data insights and leverage infinite opportunities to simulate proactive
# and reactive changes. So digital twin is a complex domain. If we ask 10 people to define
# what is a digital twin, we might get 11 different definitions. So let's see how AWS defines it. Simply put, a digital twin is a living
# digital representation of a physical system that
# mimics the looks, behavior, and state of the physical system
# to drive business outcomes. For example, imagine a digital twin of a smart home, with interconnected sensors, and IoT devices collecting
# data about physical items in the home, allowing you to visualize
# and control security, access temperature, lighting, and other home appliances remotely. Why do you do this? You do this to monitor and reduce energy and water consumption, and increase occupants'
# health, safety, and comfort. But digital twin building is
# a complex, time-consuming, and a costly operation, and it requires specialized
# developer skills that not every customer has. Let me go back to the digital
# twin of a home example. In order to have a proper digital twin, you need time series IoT data sensors, video data from camera feeds, and data from a variety
# of other home appliances, like dishwashers, washing
# machines, and what have you. You would even need 3-D
# visualization or 3-D drawings of your home in order to
# visualize and operate things in their natural context. And what happens when you
# replace your old 4-D machine with the new one? How do you update the 3-D model and bring new data into the system? Similarly, what about when you plan to
# change all your light bulbs? Now imagine the magnitude of work that will go into building
# a digital twin of a factory. With AWS IoT TwinMaker, you can easily get started
# with creating digital twins of real world systems, such
# as buildings, factories, industrial equipment and production lines, and use them in web applications
# that operators can use to monitor and improve operations. So IoT TwinMaker gives you the ability to use existing data
# from multiple sources. So you don't do not have to bring data to the IoT TwinMaker. So IoT TwinMaker connectors go
# to to the data and fetch it. So, you can also create
# virtual representation of any physical environment and combine existing 3-D
# models with real world data. So, you can now harness digital twins to create a holistic
# view of your operations with less efforts. So how does digital twin work? Let me explain you a little bit. So AWS IoT TwinMaker
# provides you a workspace, which is a top level container for your digital twin application. It also serves as a security
# boundary to manage access to the application and its resources. With IoT TwinMaker, you get
# tools to model your system by using an entity component
# model knowledge graph. This entity component model
# contains entities, components, and relationships between
# these entities and components. So what are the entities? So entities are digital
# representations of the element in a digital twin. These elements can be a
# piece of physical equipment, a concept or even a process. And obviously these entities have components associated with them. These components provide data and context for the associated entity
# with the help of connectors, and you can have a lot of
# different types of connectors. You can use building connectors or create your own connectors if required. Similarly, you can use existing
# 3-D models and drawings combined with entities and components to augment a three
# dimensional representation of your digital twin and then
# view it in Grafana dashboard. Let's see a TwinMaker in action. So I will switch to the laptop where I have already recorded a demo. So here, you see I'm logged
# into the AWS console, and I have already configured
# a couple of workspaces in the IoT TwinMaker. So let me show you one of the
# demos called CookieFactory that is available in the GitHub for you that you can use and
# deploy within your account. So let's start with this demo. So, as you can see, I have already created a
# workspace called CookieFactory. In that workspace, there
# are multiple scenes. So what is a scene? Scene, you can represent
# a room in your home or a factory floor as a scene,
# including, you can have, for example, if you have a building, and you're representing a
# building as a digital twin, you can represent an
# entire floor as a scene, and obviously, you can have
# as many scenes as you want to create a digital twin. And there are obviously a
# lot of entities pre-created for this demo that you can use. And entities could have a hierarchy, so you can have parent child entities, and obviously I have imported
# a lot of resources that we, 3D models and resources, that we will use to
# build this digital twin. So what kind of 3-D
# models IoT Maker supports? IoT Maker supports GLTF format
# and other binary formats. So GLTF is a graphic
# language transmission format, which is very web friendly. All right, so let's open the CookieFactory scene, and you can see that
# the entire factory floor is represented in a 3-D environment, and you can see a lot of cookie lines, mixers, and a lot of things
# happening inside the factory. All right? And you can see these 3-D
# diagrams are connected with the help of tags and
# a lot of other information. So components and tags. So you can call tag as an anchor as well. That's how you connect digital
# twin 3-D model with its data, All right? So you can also see there
# is there is an hierarchy between different entities. Similarly, you can actually run queries
# for your digital twin, IoT TwinMaker digital twins. For example, if you
# have a lot of entities, and you have a lot of hierarchy
# within the entity component, then you can use particle,
# which is a SQL query language to query your entities and components. And if your entities and
# components have relationships, you can even represent them visually. So, within the visual graph. So obviously, in this demo,
# we have a lot of information. So, and since I selected mixers, so you can see a lot of mixers coming in. All right, but how does a
# factory operator see all that? Factory operator is not logged into the
# IoT TwinMaker console, and they are not looking at
# the console all the time. So they use the Grafana dashboard. So, developers can build
# Grafana application for the factory operators. For example, you can see
# in this Grafana dashboard, there are already a lot of panels there. You can even bring in video
# feed, Kinesis's video, through Kinesis's video stream
# for your factory operators, so that they can see
# where action is happening, what's going on. They can actually help
# their staff become more safe while working in the factory environment. So, I will remove this video feed, so that I can actually
# show you the same 3-D model that we have seen earlier in this view. And here you can see, one of the mixer at the
# bottom is turning red, and there could be a problem
# going on with this mixer, and the factory operator can easily tell where this mixer exists
# within this factory floor, and how they can actually
# use this information to help people around this mixer, so that they are aware of the problem and they can actually be more safe, rather than being in danger. So that is the beauty of viewing
# it in a digital twin way, together with the 3-D graphics. So, but now we have a challenge. So, challenge is this CookieFactory is running on the fossil fuel energy. They want to improve, they wanna have a better energy mix, and they wanna implement
# windmills, wind farm. And as a developer, our job is
# to actually make this happen. So what we will do, we will create a digital twin
# of a windmill very quickly. So I have already created a
# workspace called Windfarm, and you can see, there is no scene and
# no entity created yet. So what I will do, I will
# quickly create an entity, give it a relevant name,
# for example Windmill 001, and after creating the entity, I will associate a
# component with this entity, and this component is
# actually getting data from IoT SiteWise. So, that's why I'm using
# IoT SiteWise connector. And I have already
# configured an asset model within the IoT SiteWise. So what I will do, I will just select that
# model name and the asset. But what does this asset include? So this is an asset of a windmill, so it is actually capturing
# the speed of the wind. Raise your hand if you know the name of the device used
# for measuring wind speed. So, the name of the device is NMO meter. All right, so I will click add component, and this entity is created
# together with the component. So let me show you, how does it look like? How does that model look
# like in this IoT SiteWise? Very quickly. So, I will open SiteWise within
# the console in new window. Now you know what kind of
# tabs I was talking about. Everything is in the new tabs. So as you can see, the
# model name is Windfarm, and within this Windfarm model, I have associated an asset,
# which is Windmill 001. And what kind of measurements
# I am capturing is the speed, which is in rpm. And this is the mock data that I'm getting from one of the Cloud 9
# instances behind the scene. I actually went ahead and
# created the IoT SiteWise monitor, and through the portal, you
# can see there are a lot of, you can create dashboards. So I have already created dashboard, just to see how does it look
# like for the factory operators, plant operators, like how they can see, how they can use SiteWise monitor to track what's going on within the factory. All right, so let's go back,
# and now we have the entity, I have already imported few 3-D assets. So let's create the scene now. So I will use create scene option here, and obviously give scene a relevant name. So scene name is Windfarm, and in this modeling window,
# I will add a 3-D model. So as I told you, I have
# already imported a 3-D model, which is Windmill. So I will import this GLTF Windmill, and obviously it's too small,
# so what I will do, I will, actually, it's too big. So what I will do, I will click it and scale
# it to appropriate size, so that you can see actually
# how does it look like. All right, and I might
# have to zoom a little bit because it's still not visible. So I will zoom it, and now you can see that
# windmill that we are going to use for powering the factory,
# the CookieFactory. But this windmill doesn't
# look like a real windmill, it's very dark here. So let's bring some light into the action. So what I would do from the settings, I will actually set up
# the environmental preset and make it neutral. I could also use a 3-D
# light on this device, but again, if you have
# a lot of 3-D graphics, you do not wanna put light
# on every each one of them. You wanna use this global preset, so that you can create lights
# for the entire environment. All right, so what's next? I mean, we have already
# created a 3-D model. So what I will do, I will
# attach a model shader, right, with this 3-D model. So I could attach a tag. For example, tag could
# be a speed, it could be, I can have multiple tags
# to a 3-D graphics model. It could be how many rpms are going on, and we can also attach model shader, so that we can change the
# color of certain models based on some parameters, some threshold. So let's see that in action. So I will add a model shader, and I will attach the entity. This is how you bring data
# together with the 3-D model. So what I will do, the entity we created
# earlier, that Windmill 001, I will attach it to this windmill. And I'm interested in the speed property, which is by the way, the only property we have
# data coming in through. And what I will do, I will also attach a
# rule together with this, so that we can represent this
# shader in multiple colors based on the speed of wind. So what I have done, I went
# ahead and actually changed this, these different expressions. For example, if speed is less than 100, I want to make sure this
# shade shows the red color. Similarly, if the speed is
# greater than or equal to 100, I want to show the color
# in different color, show this here in different color. For example, in this case,
# I choose the green color. So that means speed of
# wind is good enough, and we are getting good electricity. All right, other than that, we can also create virtual cameras that are pointing to certain devices, and we can have virtual camera, let's say, in every room of
# the factory or a building, so that operators can reach directly to that place very quickly. They don't have to actually
# scroll and, you know, navigate around the 3D environment. So you can have a lot of different cameras pointing to different
# devices or equipments. All right, so after adding the camera, now you can see the camera
# is also in the scene. Now what I will do, I have already created
# a Grafana workspace, so I will navigate to the Grafana, and there you can see in a minute that I have already created a workspace. And by the way, for this workspace, I have already set up all the permissions, so that I can access to TwinMaker data and the other way around because the application is
# in the Grafana dashboard. So here you can see what I'm doing. Now I will create a new
# dashboard, add a new panel, and I can add different panels. For example, in this particular scene, you are seeing that time
# series panel is coming up and from the query I will
# select a history by entity, and I'm selecting all that
# entities that I have created, like Windmill, and component name is WindMillMetrics. So now you can see the
# data that is the mock data that is coming to this particular, through this particular windmill is mapped to this time series. All right, so I will apply it
# and, but this is not enough. You wanna see this in
# graphics in a 3-D way, right? Like just having these
# line charts is not enough. So what I will do for my
# operators, plant operators, I will add IoT TwinMaker
# scene viewer panel, and we will name it like, Windfarm, and in the same way, I will associate it
# with the Windfarm scene that is coming through the IoT TwinMaker, and you will be able to see
# this scene live on the screen. So what I did, I selected the same properties, and now you can see this
# windmill is in green color. Can you tell me why this
# windmill is in green color? Because the data is, the speed of the wind
# is more than a hundred. So if the speed of the wind
# is going down below a hundred, the color should change to something else, and it changed to red. All right, that's it for the demo. I will switch back to the PowerPoint. So you can deploy this CookieFactory demo in your account today. Just follow this Github
# link for more instructions. Enough with the fictitious factory. Let's talk about a real factory now. To tell us more about Nortvolt's approach to sustainable manufacturing, I want to invite Marcus, but first let's watch this
# inspiring video footage that introduces the Nortvolt's vision. - [Narrator 1] The demand
# for electrification and the demand for lithium ion
# batteries is growing so fast that we're going to
# need to scale production at a really incredible pace. - [Narrator 2] We're building one of the largest
# battery plants in Europe. - [Narrator 3] Next step is
# beyond building more batteries, it's also building greener batteries, - [Narrator 1] and recycling, bringing as much of the capacity back. - [Narrator 4] Those
# batteries are then becoming new raw materials for next
# generation of battery production. - [Narrator 1] We already
# had a world class team. - [Narrator 3] It's focusing on investing into a sustainable future, building a fully circular economy. (inspirational music) (birds chirping) (upbeat music) (electric trill) - Thank you Sajid. My name is Marcus Ulmefors, and I work with the data
# platform for Northvolt factories. I'm delighted to share our
# story with you all here today. Before talking about scaling
# the digital factories for battery manufacturing, I want to cover some background
# and set the scene a bit. We begin with the global
# sales of electric vehicles. So in 2022, the first half of 2022, the global market share reached over 9%. This is excluding hybrids,
# fully electric only. Now let's use the same numbers, but with one additional feature. Mapping on the right here, we have the global total
# manufacturing capacity of lithium batteries. So to support 6% of global
# electric vehicle market share, in 2021, the production of
# lithium iron batteries was 300 gigawatt hours. So how much is a gigawatt hour? That's enough to build
# 15,000 electric vehicles and fully charged. That electrical energy is enough to drive 6 million kilometers. That's 150 laps around the equator. Now, so let's make a little
# prediction towards the future, extending this to 2030. So who believes with this development that we'll need over a thousand
# gigawatt hours per year by 2030? Okay, great. How about more than 2000, right? It turns out we'll need even more. So industry experts. Normally I talk about
# numbers exceeding 4,000, that's 10 x 2021, and lots of expert actually state numbers that are around 6,000. So that's literally off the
# charts in this visualization. Now assuming that a large gigafactory has a capacity of 30 gigawatt hours, that means more than 100 gigafactories before the end of the decade. What drives these numbers? So far, I talked about electric vehicles, that's an obvious visible example, but we will need electrification
# and lithium batteries. Also for energy storage on the
# grid, and for powering buses, trucks, boats, ferries, and
# even commercial passenger flight before the end of this decade. So to make enough batteries and factories to meet this demand, we will
# have a race against the clock. Welcome to Skelleftea. This is an eight hour
# drive north of Stockholm, the capital of Sweden. This is a site for
# Northvolt's's first gigafactory. The factory is called Ett, which is Swedish for one. Fully built out, this will
# have enough capacity to power one million electric vehicles per year. And where do we stand today? The buildings you see in this image represent one quarter of
# the full appliance capacity. In December 2021, we assembled
# our first battery sale, and in 2022, we made our
# first customer deliveries. This is real now and
# it's just the beginning. So what's special about
# Northvolt and this factory? Let's start with energy. This location is chosen deliberately for access to 100% renewable energy from nearby rivers and wind. It's also a manifestation
# for the strategic investment in vertical integration. The obvious one is to sell
# production that we know, but before that we also make
# our own battery chemistry for the electrode that is
# called active material. In other Northvolt sites,
# we design, manufacture, and operate battery packs or systems, and by end of life, battery packs are
# essentially high grade ore, and that is perfect for recycling. For that reason, we are building already a
# giga scale recycling plant at the very same site, and the output of this
# recycling process feeds back into the active material manufacturing. So now we, we are basically closing the
# loop with this co-location, so closing the loop of
# circular manufacturing, and we replace the standard
# global supply chain with a five minute walk. Vertical integration is
# great for sustainability, and it also opens the door
# for flexible data sharing between links in the value chain that enables more sophisticated
# modeling and deeper insight. Imagine not only making the
# world's greenest batteries, but also the world's smartest. How would you go about that? Let's dive into the
# technical architecture. So now before we talk about scale, we're going to cover three aspects of the technical architecture. Starting with monitoring and then controls and the data platform. We'll start with talking
# about the data sources and fundamental monitoring. In a manufacturing setting, we interact with equipment that isn't designed to
# communicate over the internet. Very often our data source is a PLC, which specializes in controlling
# mechanical equipment. Our environment starts way at
# the left with the IoT Gateway, which is an edge computer running our own
# Yocto-based Linux division. Running on that gateway, we
# have the mapper software, which provides an
# abstraction for the equipment that helps us reduce complexity
# in our cloud environment. The mapper collects data over one of our support
# investors and protocols. For example, OPCUA, HTTP Rest, or SQL. Going down to the bottom row, you see how we use IoT core
# to generate certificates, so that we cannot authenticate
# to the correct account and start streaming data into
# the Kinesis Data Streams. I've now so far talked about
# this IoT gateway and mapper as a computer running some software. In reality, this IoT platform runs on K3S and K3S is a lightweight
# Kubernetes distribution that is specifically designed for these IoT production workloads. The physical IoT gateways
# are the worker nodes in the factory, and the
# control plane runs in the cloud in our AWS accounts. The mapper software is deployed
# as highly available pods running on a pair of IoT gateways. Fully built out, a
# typical factory will have thousands of these gateways, collecting data from
# millions of data points. The actual hardware can range from a small Raspberry Pi-like
# device for light monitoring to more powerful machines for onboard GPUs to run inferences of
# machine learning models at large data sets. For example, images. Managing software running
# on thousands of devices requires reusability and
# flexibility and customization. So we have a main repository
# where every release is tagged with its specific destination. Once reviewed code is merged, Launcher Fleet deploys the
# corresponding helm charts to the K3S cluster. Pods with the tagged
# released will now start in the right gateways, communicating with the right
# manufacturing equipment. Within monitoring, broadly, we want to solve three use cases. The first is near realtime
# monitoring for raising alerts and making fast decision. Second, we want to do investigation
# analytics on larger data sets, maybe high resolution data that was collected a long time ago. And third, we want to join this
# data with contextual data within traceability to make
# flexible joints and enhance, for example, event data
# and long running processes. So that is the middle road
# that runs on Kinesis, Lambda, RDS, PostgreSQL, and visualizing
# tools such as Grafana. For investigations and analytics, we use the top row here, where we repartition raw data and store as optimized Parquet files, so that we can serve through
# Athena for larger queries. We can also perform the
# joints with contextual data for the same time window using Redshift. Monitoring is the first step. It's a crucial step, and now, let's go further
# and start interact with the factory. Also running here in a cloud
# environment is software that controls critical
# features and functions of our manufacturing line. We'll start with the bottom right corner with the business systems, ERP and PLM. ERP, or Enterprise Resource Planning, is where you have central
# management of company assets, like cash and inventory. It's also where you'll see
# transactions for purchase orders, production orders, and sales orders. PLM, Product Lifecycle Management, is the definition of a product. For example, a battery
# sale of specific model. This is also the source of
# truth for quality tolerances, product design, and the
# manufacturing processes. So now, let's consider an example where these systems all interact. It starts with the ERP
# releasing production order, and now a battery cell moves towards the next manufacturing step, let's say an extra machine. Images are taken and then analyzed with
# computer vision algorithms to produce an event with a result. Our mapping software now grabs that data and streams it up to Kinesis. Using production order
# information and the event data, we can go to PLM and request the corresponding
# quality control plan for this process for this battery cell. Now we can validate that every
# single critical measurement is within defined tolerances. This whole procedure runs
# serverless in Kinesis, Lambda and DynamoDB. Ramping a gigafactory
# is extremely exciting, but let's say, it's not
# always smooth sailing. So what happens when
# something doesn't really go according to plan? For example, if a measurement
# is outside of the tolerances, a nonconformity alert is raised and saved in the traceability
# document of the battery cell. The quality team now has
# the mandate to decide whether or not to scrap the cell or if it's released further. This decision is recorded in the top right where you see the purpose
# built web and mobile apps. These communicate with a backend through the great graphical endpoint. Now what happens if a
# non-conforming material proceeds in the manufacturing line? Well, the equipment will
# know the material id. So we can ask a cloud service through the API gateway
# in the bottom left, whether or not further
# processing is allowed. If the response is negative,
# the operations will halt. Every interruption and quality deviation is captured and recorded
# in near real time. An instant access to this data allows us to course correct right away on the manufacturing line. In this architecture,
# you see four lambdas. In reality these are communication
# and integration patterns. And since we run many
# application parallel, there are quite a few
# more instances of them. So for a section of the factory, how many lambdas do you
# think we'll have here? Maybe 20? Maybe 40? Today, there are more than a hundred. So here, you have some examples of how cloud software uses
# data in near real time to automate and control our
# manufacturing processes. Of course, we also take a copy of this
# data, store it, refine it to drive analytics. And for that we'll take a closer
# look at the data platform. Data is strategic at Northvolt. It starts with traceability, which essentially allows us to track exactly what happens to
# every single cell component in every manufacturing process. High resolution data
# constitutes from factories, and labs constitute a unique asset that we can use for optimizing operations and for developing better products. Within its factory, will
# have thousands of gateways with hundreds of thousands
# of data records per second. So we need a flexible and
# scalable data platform that can provide us with
# the technology we need for monitoring analytics, data science, and machine learning. We manage hundreds of data sets
# in the data platform today, and here we're going to
# look at three categories of data flows that are
# specifically designed to power analytics and for
# data driven operations. Let's start with the center row. That's where we have contextual data. This data comes from
# the manufacturing line, from equipment or from
# software applications running in the cloud, with or without
# the human in the loop. This can be immutable event streams or mutable data such as
# states or identities. Every right operation
# to DynamoDB is consumed through change data capture
# for DynamoDB streams. We then take these hundreds
# of data sets and filter and map them and then
# join with other data sets to create this specifically
# designed data sets for analytics. The analytics datasets are
# then used by technicians, engineers and managers to
# prioritize initiatives, track progress, and report on results. We use an ELT pattern with
# Extractor S3, load into Redshift, and transform within Redshift using DBT. Everything orchestrated using Airflow. The bottom row represents
# electrical measurements. So from ready cells in a lab, this is time series data
# with high resolution and long duration, can be many months. And we use this data to
# do performance analysis and to perform product R & D. In the top row, we upload images and other
# large files directly to S3. This can be, for example,
# photos or camera images from the manufacturing line that allows us to train
# machine learning models for vision based defect detection systems. We then use distributed training
# with multiple cloud GPUs and deploy the most performant models onto the IoT gateways with onboard GPUs, for inference on the manufacturing line. So those are our fundamental
# features of the architecture that we run in AWS. That's great. So let's go onto scaling. Greenfield factories
# have no existing legacy. That allows us to use Cloud
# Native and Serverless strategy. How do we design this? What are our principles? The gigafactories are huge
# investments, billions of dollars. That means every single minute of downtime is very expensive. So using Cloud Native
# technologies allows us to increase reliability. We achieve security by
# compartmentalization and zero trust across
# our cloud architecture, which use appropriate
# separation granularity to decrease blast radius. And then to scale quickly, we use many excellent
# services provided by AWS for network and compute and storage, but we also need to manage the complexity of a growing system. So there we need to be
# able to combine and balance the global reusability with
# site-specific optimizations. To scale a digital blueprint,
# we needed to be modular, a single concept across factories without sacrificing the
# ability to create optimizations for a specific factory or area. And Northvolt's mission,
# which an admission, is to create the world's greenest battery. So using AWS, we can use optimized
# technologies for the cloud and not least, flexible
# utilization of shared resources. For example, using Serverless. On top of that, the Stockholm EU North 1 region runs on a 100% renewable energy, which fits our mission perfectly. With a high quality platform, reliability and development
# speed can coexist. So from a software release perspective, our factory shouldn't be
# different from a flexible web app, meaning we should support
# Blue/green deployments and Canary deployments. Taking all this into
# account, where do we end up? Introducing Northvolt
# Cloud Factory modules. We start with a physical
# layout of a factory. We then create a
# dedicated building account to start deploying the K3S cluster with hundreds of IT gateways. And here's where the maps authenticate the right building account and start ingesting streaming data into Kinesis data streams. This is also where the
# back end Lambdas will run that we looked at before. In the core account, we use
# functionality for features that need to be shared across buildings. For example, DynamoDB for
# operational transactional data, but also RDS instances, Elastic Kubernetes Service, OpenSearch, and raw data industry. The data account is where we refine data, internally these data sets, we'll find here Redshift
# and Airflow and DBT, but also the MLOps platform. You can think of this
# entire account as a DAG, with data being replayable from source, and also with data in general
# doesn't flow backwards. So that wraps up the
# factory specific accounts. What do we need more than this? In fact, it turns out that
# we need a little bit of help across the entire ecosystem. For example, the share account. This is where we run features that help development and operations. We manage Secrets, Elastic Container Registry,
# and our observability platform. For example, OpenSearch surveys,
# Prometheus, and Grafana. Network. The networking backbone has
# transit gateways, firewalls, and direct connect. This connects not only our physical sites, but also the controls, the incoming and outgoing
# data between our AWS accounts. And this account also
# provides the integration with other cloud providers,
# who shall remain unnamed today. (audience chuckles) And in a global account, we have a central graphical endpoint, providing like consistent
# front end user experience for our applications. The backend is accessed through a factory specific
# federated endpoint running in the core account. This enables access control
# through user roles and location. All right, now we have our first factory. Are we done? No. We scale. We need more factories. So let's add one more, and here we create the
# the same integrations for in the global accounts, and we add the core data platform. The real strength of
# the concept is visible in the building accounts because here, depending on the geographical location and the product that we make
# will lead different processes and therefore different building types. With the cloud factory modules, we can represent these differences without changing our concept. This remains consistent. All right, so where does that take us? To achieve reliability and
# optimized performance at scale, we need excellent tooling
# for infrastructure as code. As technology moves
# towards everything as code, what becomes our vision? You probably guessed it
# by now, factory as code. Why not something like this? The world will need hundreds
# of new battery factories for us to transition to
# a cleaner energy future. At Northvolt, this is real now, and we are just getting started. Thank you so much for
# listening to our story today. I hope you will remain with
# us for the exciting future. Maybe already on Wednesday or Thursday in one of the deep dive chalk
# talks with my colleagues. With that, I want to welcome Sajid back on stage, and thank you so much. (audience applauds) - [Audience Member 1] Amazing. - Thank you, Marcus. We are happy to support
# Northvolt in their efforts to decarbonize the energy
# for a greener future. This is the perfect time
# to grab your phone camera and take a picture of this and
# some of the following slides. You can use these resources to learn more, and you can also read more about the connected factory
# model in Northvolt's blog post. And if your schedule is not fully booked, here are some of the
# sessions you should attend. You might already have
# some of these sessions in your schedule. And if you have time and interest
# in creating digital twins of aerospace use cases, then please check out
# IoT TwinMaker workshop 1:00 PM today at Caesar's Forum. Similarly, don't forget
# to attend the Chalk Talk with Northvolt on Wednesday,
# 12:15 PM in Caesar's Forum. Let me ask you one more time, raise your hands if you're responsible for sustainability in your company. (chuckles) All right, so in the end, I will leave you with this
# quote from Jeff Bezos that says, "We must conserve what we still have. We must restore what we have lost, and we must grow what we need to live without degrading the planet
# for future generations." It was a pleasure presenting
# in front of you today. Please don't be the Tab-Tsundoku like me, and don't forget to
# complete the session survey. Thank you very much. (applause)

# %%
# Acquire YouTube's full transcript for insights.
# Utilize open-source NLP models via Transformers library.
# Transformers by Hugging Face: Leading NLP platform.
# Pretrained models cut compute costs and save time.
# Translate transcript using pretrained model.
# Hugging Face offers 2,500+ translation options.
# Experiment by adjusting "model_checkpoint" variable.



# Import the required function 'pipeline' from the Transformers library
from transformers import pipeline

# Replace this with your own checkpoint
# Specify the pretrained translation model you want to use
model_checkpoint = "Helsinki-NLP/opus-mt-en-es"

# Create a translation pipeline using the specified model
translator = pipeline("translation", model=model_checkpoint)

# Define the maximum sequence length
# This is the maximum length each segment can have
max_length = 512

# Split the input text into smaller segments
# Break the long transcript into smaller pieces to fit the model's input size
segments = [transcript_text[i:i+max_length] for i in range(0, len(transcript_text), max_length)]

# Initialize a variable to store the translated text
translated_text = ""

# Iterate through each segment and translate it
# The following loop processes each segment, translates it, and adds the translation to 'translated_text'
for segment in segments:
    # Use the translation pipeline to translate the current segment
    result = translator(segment)
    # Append the translated text from the current segment to 'translated_text'
    translated_text += result[0]['translation_text']

# Print the final translated text
# Display the translated transcript
print(translated_text)
# Out:
# Si su respuesta es sí, usted está en el lugar correcto. Bienvenido a todos. Mi nombre es Muhammad Sajid. Soy un Arquitecto de Soluciones en AWS. Conmigo, tengo Marcus Ulmefors, Director de Plataformas de Aprendizaje de Datos y Máquinas en Northvolt. Él está aquí para hablar de cómo la primera gigafactoría casera de Europa, Northvolt, está produciendo baterías de espalda sostenibles en su fábrica conectada.Un hábito de mantener abiertas las pestañas de mi navegador. Hay un término especial para esto llamado "Tab-tsundoku". Tsundoku es una palabra japonesa para adquirir y acumular libros impulsivamente, sin tener la intención de leerlos. Así que levanta las manos si tu navegador se ve así a diario. Bienvenido al club. (risas) Pero no podemos seguir abriendo nuevas pestañas para siempre. Cualquier cosa que no podamos seguir haciendo para siempre es obviamente no sostenible. Así que no estás aquí para escuchar mis hábitos insostenibles.0 sesión de ruptura, donde aprenderá cómo los clientes de la fabricación están aprovechando AWS en su viaje de sostenibilidad. Permítanme hacerle una pregunta. Levante su mano si usted es responsable de la sostenibilidad en su empresa. (murmullos de audiencia) Esperaba que cada uno de ustedes para levantar sus manos. ¿Sabes por qué? Al igual que la seguridad, la sostenibilidad es responsabilidad de todos. Echemos un vistazo a la agenda. Hoy, usted aprenderá cómo los fabricantes pueden utilizar los datos para ser más sostenibles.¿Ogies que usted puede utilizar para optimizar las operaciones de fábrica? También le mostraré una demostración corta de AWS IoT TwinMaker, y obviamente Marcus de Northvolt compartirá su o su experiencia de utilizar AWS para operar la fábrica conectada. Al final, le dejaré con un poco de llamada a las acciones y los recursos de aprendizaje. Así que estás listo? Mostrar un poco de emoción. ¿Estás listo? - ¡Sí! - ¡Sí! (audiencia vítores) (miembros de la audiencia riñen) - ¿Sabes cuál es la temperatura media de la Tierra? Levante sus manos. Hoy, el av globalLos 20 años más cálidos registrados han sido en los últimos 20 años. Así que la investigación dice que la temperatura global promedio puede subir de tres a cinco grados para finales de este siglo, hasta 2100. Los científicos también nos dicen que tenemos una ventana limitada para hacer avances sin precedentes con el fin de limitar el calentamiento global a 1,5 grados Celsius para el año 2050. Y por qué esto es importante, esto es importante para evitar problemas climáticos graves, incluyendo el calor.Pero mi pregunta es, ¿por qué la temperatura de la tierra está aumentando? Mucho calentamiento global está ocurriendo debido a los gases de efecto invernadero generados por las actividades humanas. Entonces, ¿cuáles son los gases de efecto invernadero? Los gases de efecto invernadero atrapan el calor en la atmósfera terrestre que a cambio, hace que el planeta sea mucho más caliente. Hay muchos gases de efecto invernadero diferentes, incluyendo dióxido de carbono, metano, óxido nitroso.El término colectivo "gases de efecto invernadero" también va por el nombre más científico llamado equivalente de dióxido de carbono. Y este es el 50 mil millones de toneladas, o 50 gigatones, que estamos tratando cada año. De estos 50 gigatones, ¿cuánto crees que contribuye el sector manufacturero? Aproximadamente 21%, o aproximadamente 10 gigatones, cada año. Permítanme poner esto en perspectiva. Así que un gigatón es aproximadamente 200 millones de elefantes, si se apilan verticalmente uno encima del otro, se estirarían hasta el final.De ahí que el 10 gigatón sea 10 pilas de elefantes que se extienden de la tierra a la luna, y no tenemos que estar vivos y esperar hasta finales de siglo para ver las consecuencias del cambio climático. Por ejemplo, este año alrededor de 33 millones de personas, incluyendo 16 millones de niños, han sido impactados en mi país natal, Pakistán, por la devastadora inundación causada por el cambio climático. Así que 33 m ...

# %%
# Import the necessary libraries
from transformers import pipeline, AutoTokenizer

# Instantiate the tokenizer and the summarization pipeline using a pre-trained model
tokenizer = AutoTokenizer.from_pretrained('stevhliu/my_awesome_billsum_model')
summarizer = pipeline("summarization", model='stevhliu/my_awesome_billsum_model', tokenizer=tokenizer)

# Define the chunk size in number of words
chunk_size = 200 # you may need to adjust this value depending on the average length of your words

# Split the transcript text into individual words
words = transcript_text.split()

# Split the transcript text into chunks of the defined size
chunks = [' '.join(words[i:i+chunk_size]) for i in range(0, len(words), chunk_size)]

# Initialize an empty list to store the summaries
summaries = []

# Loop through each chunk and summarize it
for chunk in chunks:
    # Generate a summary for the current chunk
    summary = summarizer(chunk, max_length=100, min_length=30, do_sample=False)

    # Extract the generated summary text
    summary_text = summary[0]['summary_text']

    # Add the summary to the list of summaries
    summaries.append(summary_text)

# Join the individual summaries back together into a single final summary
final_summary = ' '.join(summaries)

# Print the final summarized text
print(final_summary)
# Out:
# I'm a Solutions Architect at AWS. With me, I have Marcus Ulmefors, Director Data and Machine Learning Platforms at Northvolt. You will meet Marcus very soon. Both me and Marcus are from Stockholm, Sweden. There is a special term for this called "Tab-tsundoku" I expected every one of you to raise your hands. You know why? Just like security, sustainability is everyone's responsibility. Let's look at the agenda. Today, you will learn how manufacturers can use data to become more sustainable. What are some of the modern technologies you can use to optimize factory operations? I will also show you a short demo of AWS IoT TwinMaker. greenhouse gases trap heat in earth's atmosphere that in return, makes the planet much hotter. There are many different greenhouse gases, including carbon dioxide, methane, nitrous oxide, and many more. The collective term "greenhouse gases" goes by the more scientific name called carbon dioxide equivalent. the 10 gigaton is 10 stacks of elephants stretching from earth to the moon, and we don't have to wait until the end of the century to see the consequences of the climate change. For example, this year around 33 million people, including 16 million children, have been impacted in my native country, Pakistan, by the devastating flood caused by climate change . there is no sign of fresh water, just the stagnant, contaminated water, acting as a fossil fuels remain the dominant source of energy for industry. The manufacturing industry contributes significantly to greenhouse gases, and use, and manufacturers use a lot of water and energy. That's the reason, I mean, manufacturing are also the most targeted industry in sense of sustainability. We are experiencing the fourth industrial revolution live. The first revolution brought mechanical innovations, like steam engine, cotton spinning, and railroads. The fourth revolution brought the mass production through assembly lines and electrification. ISA95 is the international standard for the integration of enterprise and control systems, which is a traditional model before the cloud era. This model consists of field and control and management levels. The management level consist of basic control systems like supervisory control and data acquisition, or SCADA, and programmable logic controller and distributed control systems. So historically, this monolithic model was good before the clouds and edge computing era, and it created data silos, and integration With the cloud and open platform communication unified architecture, the traditional model has evolved significantly, and IT-OT divide is minimized, and operations technology environments are leveraging more IT solutions in the cloud to improve productivity and efficiency of production operations. And why did they do this? To run latency critical system on the edge close to the factory floor where all the action happens, and send volumes of data to the cloud for analytics, BI, and machine learning operations. There are a predictive maintenance can increase production line availability by 5-15% and reduce maintenance costs by 18-25%, according to McKinsey . with predictive maintenance, you can improve overall equipment efficiency, OEE, and lifespan of a machine even further, more than even 22 years. So digitization enhances shop floor safety as well. only 39% of manufacturing executives said they were able to scale a use case outside of a single product's production process . only 44% said recent modernization efforts have provided them with actionable data, while 19% have not harnessed any data inside, and I'm going to focus on just a few AWS services that fast track adding digitization to your factory . So today, industrial companies want to ingest, store, and analyze IoT data closer to the point where data is generated, where all the action happens, which is the factory floor. So why they wanna do that, to enable predictive maintenance, improve overall equipment efficiency and enhance worker safety and even  ...

# %%
import textwrap
import openai

# Function to split the text into chunks of a specified size
def split_text_into_chunks(text, max_chunk_size):
    return textwrap.wrap(text, max_chunk_size)

# Set your OpenAI API key here
openai.api_key = ""

# Define the maximum chunk size for splitting the transcript
max_chunk_size = 4000

# Split the transcript text into manageable chunks
transcript_chunks = split_text_into_chunks(transcript_text, max_chunk_size)

# Initialize an empty string to store the generated summaries
summaries = ""

# Loop through each chunk of the transcript and generate summaries
for chunk in transcript_chunks:
    # Create a chat completion request using GPT-3.5 Turbo model
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"{chunk}\n\nCreate short concise summary"}
        ],
        max_tokens=250,   # Set the maximum length of the response
        temperature=0.5   # Control the randomness of the output
    )

    # Extract the generated summary from the response and add it to the summaries string
    summaries += response['choices'][0]['message']['content'].strip() + " "

# Print the final combined summary
print("Summary:")
print(summaries)
# Out:
# Summary:
# In this Level 300 breakout session, Muhammad Sajid, a Solutions Architect at AWS, discusses how manufacturers can leverage AWS to become more sustainable. He highlights the importance of sustainability and the impact of greenhouse gases on global warming. Sajid also introduces Marcus Ulmefors, Director Data and Machine Learning Platforms at Northvolt, who shares their experience of using AWS to operate a connected factory for sustainable battery production. The session includes topics such as using data to optimize factory operations, modern technologies for sustainability, and a demo of AWS IoT TwinMaker. Sajid concludes by providing call to actions and learning resources for attendees. The manufacturing industry is a significant contributor to greenhouse gas emissions and resource consumption. However, with the advent of the fourth industrial revolution and the integration of data and cloud technology, there is an opportunity to improve sustainability and profitability in manufacturing. The traditional model of separating operational technology (OT) and information technology (IT) is being replaced by a more integrated approach. The ISA95 framework, which previously divided manufacturing technology into OT and IT, is evolving with the use of cloud computing and open platform communication. This convergence of IT and OT allows for improved productivity and efficiency in production operations. Sustainable manufacturing is made possible through modern technologies that allow manufacturing customers to use data to become more sustainable and profitable. Examples include lowering energy usage through occupancy detection and smart lighting, implementing predictive maintenance to increase production line availability and reduce maintenance costs, and enhancing shop floor safety through data monitoring. Data is the key enabler for sustainable manufacturing, but realizing value from data can be challenging. AWS offers services such as AWS IoT and ad services, as well as cloud capabilities at the edge, to help industrial companies digitize their factories and gain insights from their data. AWS IoT TwinMaker is a tool that allows users to easily create digital twins of real-world systems, such as buildings, factories, and industrial equipment. It provides a workspace for modeling the system using an entity component model, which includes entities, components, and relationships between them. Users can use existing data from multiple sources and combine it with 3D models to create a holistic view of operations. This simplifies the process of building digital twins and allows for monitoring and improving operations with less effort. The IoT TwinMaker is a tool that allows users to create digital twins of physical assets or environments. These digital twins are three-dimensional representations that can be augmented with data and context using connectors. The tool supports various types of connectors, including building connectors and custom connectors. Users can also import existing 3D models and drawings to enhance their digital twins. The digital twins can be viewed and managed through the AWS console and can be integrated with Grafana dashboards for real-time monitoring and analysis. The tool also supports hierarchical structures for entities and components, and users can run queries using a SQL query language called Particle. Overall, the IoT TwinMaker provides a comprehensive solution for creating and managing digital twins in various industries and applications. The challenge is to improve the energy mix of a CookieFactory running on fossil fuel energy by implementing windmills. The developer will create a digital twin of a windmill using a 3-D model and IoT SiteWise connector to capture wind speed data. The windmill model is imported and adjusted in size and lighting is added to enhance the visuals. Model shaders can be used to change the color of the model based on certain parameters. In this demo, the presenter showcases how to b ...

# %%
response = openai.ChatCompletion.create(
model="gpt-3.5-turbo-16k",
messages=[
{"role": "system", "content": "You are a technical instructor."},
{"role": "user", "content": transcript_text},
{"role": "user", "content": "Generate steps to follow from text."},
]
)

# The assistant's reply
guide= response['choices'][0]['message']['content']

print("Steps:")
print(guide)
# Out:
# Steps:
# 1. Understand the global impact of greenhouse gases and the need for sustainability in the manufacturing sector.
# 2. Learn about the ISA95 framework and its role in integrating enterprise and control systems.
# 3. Explore modern technologies that can help manufacturers become more sustainable, such as IoT, AI/ML, and cloud computing.
# 4. Discover how AWS IoT and ad services can be used to collect and analyze data from factory operations.
# 5. Explore the concept of digital twins and how they can be used to improve manufacturing processes and operations.
# 6. Learn about Northvolt, Europe's first homegrown gigafactory, and their approach to sustainable battery production.
# 7. Understand the technical architecture of Northvolt's connected factory, including monitoring, controls, and data platforms.
# 8. Explore the scalability of the Northvolt digital blueprint and how it can be applied to multiple factories.
# 9. Take advantage of the resources and sessions provided to further explore sustainable manufacturing and connected factories.
# 10. Embrace the responsibility of sustainability in your own company and consider implementing the concepts and technologies discussed.

# %%
response = openai.ChatCompletion.create(
model="gpt-3.5-turbo-16k",
messages=[
{"role": "system", "content": "You are a helpful assistant that generates questions."},
{"role": "user", "content": transcript_text},
{"role": "user", "content": "Generate 50 quiz questions based on the text with multiple choices."},
]
)

# The assistant's reply
quiz_questions = response['choices'][0]['message']['content']

print("Quiz Questions:")
print(quiz_questions)
# Out:
# Quiz Questions:
# 1. What is the average temperature of the Earth?
#    a) 10 degrees Celsius
#    b) 15 degrees Celsius
#    c) 20 degrees Celsius
#    d) 25 degrees Celsius
#
# 2. How many gigatons of greenhouse gases are contributed by the manufacturing sector each year?
#    a) 5 gigatons
#    b) 10 gigatons
#    c) 15 gigatons
#    d) 20 gigatons
#
# 3. What is the collective term for greenhouse gases?
#    a) Carbon dioxide equivalent
#    b) Nitrogen oxide equivalent
#    c) Methane equivalence
#    d) Oxygen equivalence
#
# 4. According to the IEA, how much CO2 did the industrial activity emit in 2021?
#    a) 5 gigatons
#    b) 7.5 gigatons
#    c) 9.4 gigatons
#    d) 12 gigatons
#
# 5. What is the purpose of the fourth industrial revolution?
#    a) To bring physical and digital systems together
#    b) To automate manufacturing processes
#    c) To increase global productivity
#    d) To reduce greenhouse gas emissions
#
# 6. What is the ISA95 framework used for?
#    a) Integrating enterprise and control systems
#    b) Monitoring factory operations
#    c) Optimizing energy efficiency
#    d) Reducing carbon footprint
#
# 7. What is the main challenge for manufacturers in terms of data visibility?
#    a) Limited access to operational data
#    b) Difficulty integrating IT and OT systems
#    c) Lack of cloud computing capabilities
#    d) Incompatible communication protocols
#
# 8. How can manufacturers use data to become more sustainable?
#    a) Lower electricity and energy usage
#    b) Improve equipment lifespan and efficiency
#    c) Enhance shop floor safety and comfort
#    d) All of the above
#
# 9. What is predictive maintenance?
#    a) A maintenance strategy based on historical data
#    b) Monitoring machines for abnormal behavior
#    c) Preventive maintenance performed on a regular schedule
#    d) Repairing machines after they break down
#
# 10. What is the average lifespan of a factory equipment or asset?
#     a) 5-10 years
#     b) 10-15 years
#     c) 15-20 years
#     d) 20-25 years
#
# 11. How can predictive maintenance improve overall equipment efficiency?
#     a) By reducing maintenance costs
#     b) By increasing production line availability
#     c) By extending the lifespan of machines
#     d) All of the above
#
# 12. What is the term for impulsively acquiring and piling up books without intending to read them?
#     a) Tab-tsundoku
#     b) Book-hoarding syndrome
#     c) Impulse book buying
#     d) Chronic book collecting
#
# 13. Why is sustainability everyone's responsibility?
#     a) Because it affects the environment
#     b) Because it impacts future generations
#     c) Because it is a global issue
#     d) All of the above
#
# 14. What percentage of executives surveyed by Forbes were able to scale a sustainability use case outside of a single product's production process?
#     a) 39%
#     b) 50%
#     c) 62%
#     d) 75%
#
# 15. How can AWS IoT TwinMaker be used in manufacturing?
#     a) To easily create digital twins of real-world systems
#     b) To monitor and detect abnormal machine behavior
#     c) To optimize factory operations using data insights
#     d) All of the above
#
# 16. What is the role of the digital twin in manufacturing?
#     a) To simulate proactive and reactive changes
#     b) To improve the physical twin through data insights
#     c) To create a holistic view of operations
#     d) All of the above
#
# 17. What is Northvolt's approach to sustainable manufacturing?
#     a) Vertical integration and circular manufacturing
#     b) Energy optimization and renewable power sources
#     c) Data-driven operations and analytics
#     d) All of the above
#
# 18. What is the purpose of Northvolt's Ett gigafactory?
#     a) To produce sustainable batteries
#     b) To power one million electric vehicles per year
#     c) To implement a circular manufacturing process
#     d) All of the above
#
# 19. What are the benefits of vertical integration in manufacturing?
#     a) Improved sustainability and reduced carbon footprint
#     b) Enhanced control and flexibility in the supply chain
#     c) Increased efficiency and cost savings
#     d) All of the above
#
# 20. What is the role of the IoT Gateway in Northvolt's architecture?
#     a) Collecting data from manufacturing equipment
#     b) Mapping and providing an abstraction layer
#     c) Streaming data to Kinesis Data Streams
#     d) All of the above
#
# 21. What are the three use cases for monitoring in manufacturing?
#     a) Near real-time monitoring, investigation analytics, and traceability
#     b) Critical equipment monitoring, energy optimization, and waste reduction
#     c) Inventory management, production planning, and quality control
#     d) Performance analysis, predictive maintenance, and process optimization
#
# 22. How does Northvolt handle non-conforming materials in the manufacturing process?
#     a) Raise nonconformity alerts and record them in traceability documents
#     b) Halt operations and decide whether to scrap or release the material
#     c) Verify permissions for further processing through an API gateway
#     d) All of the above
#
# 23. What is the purpose of the share account in Northvolt's architecture?
#     a) To manage secrets and provide secure access to resources
#     b) To integrate with other cloud providers
#     c) To ensure reliable network connections
#     d) All of the above
#
# 24. How does Northvolt achieve compartmentalization and security in their architecture?
#     a) By using zero trust principles and separation granularity
#     b) By implementing firewalls and transit gateways
#     c) By encrypting data at rest and in transit
#     d) All of the above
#
# 25. How does Northvolt leverage renewable energy in their operations?
#     a) By choosing locations with access to renewable energy sources
#     b) By utilizing 100% renewable energy in their data centers
#     c) By building wind farms and solar installations on site
#     d) All of the above
#
# 26. What is the purpose of the factory-specific accounts in Northvolt's architecture?
#     a) To deploy the K3S cluster and IoT gateways for specific factories
#     b) To manage data processing and analytics for specific factories
#     c) To provide a dedicated environment for factory-related operations
#     d) All of the above
#
# 27. What is the purpose of the global account in Northvolt's architecture?
#     a) To provide a central graphical endpoint for consistent user experience
#     b) To manage shared resources and facilitate cross-factory operations
#     c) To integrate with other cloud providers and external services
#     d) All of the above
#
# 28. What is the benefit of using Serverless technologies in manufacturing?
#     a) Increased reliability and scalability
#     b) Cost savings and optimized resource utilization
#     c) Faster development and deployment cycles
#     d) All of the above
#
# 29. What is the vision of Northvolt's cloud factory concept?
#     a) Factories as code, with modular and reusable components
#     b) Automated and optimized manufacturing processes
#     c) Integration of advanced analytics and machine learning
#     d) All of the above
#
# 30. How does Northvolt approach infrastructure as code in their digital factories?
#     a) Using excellent tooling for managing infrastructure
#     b) Treating factories as flexible web applications
#     c) Balancing global reusability with site-specific optimization
#     d) All of the above
#
# 31. How does Northvolt achieve reliability and optimized performance in their architecture?
#     a) Through the use of Cloud Native technologies
#     b) By combining shared resources and dedicated accounts
#     c) With a focus on security and compartmentalization
#     d) All of the above
#
# 32. What is the goal of Northvolt's traceability system?
#     a) To track every component and process in the manufacturing line
#     b) To ensure compliance with quality standards
#     c) To enable data-driven decision-making
#     d) All of the above
#
# 33. How does Northvolt utilize time series data for performance analysis?
#     a) By storing high-resolution data in optimized file formats
#     b) By performing analytics and investigations on larger data sets
#     c) By using distributed training and inference for machine learning models
#     d) All of the above
#
# 34. What type of data is stored in the data account in Northvolt's architecture?
#     a) Refined and transformed data for analytics and reporting
#     b) Electrical measurements for performance analysis
#     c) Large files such as images for machine learning models
#     d) All of the above
#
# 35. How does Northvolt handle large files such as images in their architecture?
#     a) Uploading them directly to S3 for storage
#     b) Using distributed training with multiple cloud GPUs
#     c) Deploying machine learning models for inference on IoT gateways
#     d) All of the above
#
# 36. What does Northvolt's architecture balance in terms of optimization and reusability?
#     a) Global reusability with site-specific optimizations
#     b) Efficiency with cost-saving measures
#     c) Flexibility with standardization
#     d) All of the above
#
# 37. What is the main focus of Northvolt's cloud factory modules?
#     a) Modular and reusable components for factory deployment
#     b) Standardization of factory operations and processes
#     c) Location-specific optimizations for performance and efficiency
#     d) All of the above
#
# 38. What is the advantage of the cloud factory modules concept in manufacturing?
#     a) Ability to represent different factory types with the same concept
#     b) Flexibility to accommodate site-specific requirements
#     c) Consistent application of best practices and standards
#     d) All of the above
#
# 39. How many gigafactories can be supported by Northvolt's cloud factory modules?
#     a) Hundreds
#     b) Thousands
#     c) Tens of thousands
#     d) Unlimited
#
# 40. What is the ultimate goal of Northvolt's architecture and manufacturing approach?
#     a) To create the world's greenest batteries
#     b) To accelerate the transition to a cleaner energy future
#     c) To lead the industry in sustainable manufacturing practices
#     d) All of the above
#
# 41. What is the purpose of the global sales of electric vehicles in relation to battery manufacturing?
#     a) To drive the demand for lithium batteries
#     b) To support the transition to electric transportation
#     c) To increase the need for battery production capacity
#     d) All of the above
#
# 42. How does Northvolt address the challenge of meeting the growing demand for lithium batteries?
#     a) By increasing production capacity through gigafactory construction
#     b) By implementing vertical integration and circular manufacturing
#     c) By investing in renewable energy and battery recycling
#     d) All of the above
#
# 43. What is the predicted demand for lithium batteries by 2030?
#     a) Over 1,000 gigawatt hours per year
#     b) Over 2,000 gigawatt hours per year
#     c) Over 4,000 gigawatt hours per year
#     d) Over 6,000 gigawatt hours per year
#
# 44. How does Northvolt's architecture prioritize sustainability in manufacturing?
#     a) By using renewable energy sources for power
#     b) By implementing circular manufacturing and recycling processes
#     c) By minimizing environmental impact through vertical integration
#     d) All of the above
#
# 45. What is the role of data in Northvolt's sustainable manufacturing approach?
#     a) To optimize operations and improve energy efficiency
#     b) To enable data-driven decision making and process improvements
#     c) To support predictive maintenance and quality control
#     d) All of the above
#
# 46. How does Northvolt leverage the cloud and edge computing in their architecture?
#     a) To collect and analyze data from manufacturing equipment
#     b) To enable real-time monitoring and control of factory operations
#     c) To support advanced analytics and machine learning capabilities
#     d) All of the above
#
# 47. What are the main principles of Northvolt's technical architecture?
#     a) Reliability, security, and scalability
#     b) Modularity, customization, and optimization
#     c) Sustainability, flexibility, and reusability
#     d) All of the above
#
# 48. How does Northvolt ensure reliability and performance at scale in their architecture?
#     a) By using Cloud Native technologies and serverless computing
#     b) By leveraging shared resources and task-specific optimizations
#     c) By implementing robust networking and connectivity solutions
#     d) All of the above
#
# 49. What is the key feature of Northvolt's digital factory concept?
#     a) Factory as code and modular architecture
#     b) Automated and optimized manufacturing processes
#     c) Integration of advanced analytics and artificial intelligence
#     d) All of the above
#
# 50. What is the ultimate aim of Northvolt's cloud factory vision?
#     a) To create the world's greenest and smartest batteries
#     b) To enable a sustainable and circular battery manufacturing industry
#     c) To support the global transition to a cleaner energy future
#     d) All of the above
